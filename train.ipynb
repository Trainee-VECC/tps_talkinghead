# %% [markdown]
# # RUN THIS CODE CELL TO START TRAINING
# - Add dataset folder to base directory and set its path
# - You can change batch size in config/celebV-512.yaml <br>
# - You can change device ids for multliple GPU usage <br>
# - You can change number of epochs, number of dataset repetitions and data set path in config/celebV-512.yaml <br>

# %%
# !CUDA_VISIBLE_DEVICES=0,1 python run.py --config config/celebV-512.yaml --device_ids 0,1
